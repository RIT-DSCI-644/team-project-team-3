# %% [markdown]
# All of the helper commands for filtering datasets to send just what you want to a visualization tool.
#
# Designed so you send a dataset through a series of helper function filters, then send the final filtered dataset to a function that provides an answer
#
# 20-April-2019

# %% [markdown]
# List of Helpers:
# Filters
# get_age      Gives a dataset only including tweets by people above or below (or exactly) an age
# get_sentiment_type   Gives a dataset with only positive, negative, or neutral tweets
# get_sentiment_number Gives a dataset with sentiment valusea abve or below a number (find more extreme sentiment)
# get_gender   Gives a dataset with only tweets from specified gender
# get_leaning_tweets  Gives a dataset only from liberal or conservative
# get_persons_tweets  Gives dataset with only one person's tweets
# get_race_type   Gives a dataset containing only the race entered
#
#
# Answers
# get_sentiment_count   Returns the count of tweets containing that classification of sentiment (+ 0 -)
# get_total_tweet_count  Returns number of rows in dataset
# get_retweets_per_tweet  Returns sum of retweet_count divided by number of tweets
# get_average_sentiment  Returns the average sentiment score in a dataset
# get_leaning_score Returns the political leaning score of a person
# get_sentiment_frequency  returns proportion of tweets that are a particular type of sentiment
#
# get_top_retweeted  returns a ranked dictionary of the most retweeted by their retweets_per_tweet and their retweet rates
# get_most_conservative  returns a dictionary of the most conservative by dw_score and their scores
# get_most liberal  Same as above but for liberal
# get_most_positive  returns ranked dictionary of names and average sentiment of most positive average sentiment
# get_most_negative  same as above for negative

# %%
import csv
import pandas as pd
import numpy as np

# %%
trump=pd.read_csv('trump_sentiment.csv')
clinton=pd.read_csv('clinton_sentiment.csv')
congress=pd.read_csv('congress_sentiment.csv')
all_names=congress['elite'].unique()

# %%
congress.head()
# Out:
#    Unnamed: 0  Trinary_Score  Vader_Score  \
# 0           0              1       0.5719
# 1           1             -1      -0.1027
# 2           2             -1      -0.3182
# 3           3              0       0.0000
# 4           4             -1      -0.6249
#
#                                                 text    elite  retweet_count  \
# 0  @jnblsm Thanks for reaching out.  Wes Scherman...  _Hunter              8
# 1  .@sdut Let\xe2\x80\x99s make America great aga...  _Hunter            155
# 2  'This afternoon I'm meeting w/ White House to ...  Abraham              2
# 3  My statement on the FEMA 90-10 cost-share anno...  Abraham              3
# 4  Louisiana congressional delegation wrote to FE...  Abraham              1
#
#    media  gender  dw_extr  dwextr_rs  dw_score  race  age  followers
# 0   -0.5     0.5    0.511   0.413264     0.511   0.5   69    13068.0
# 1    0.5     0.5    0.511   0.413264     0.511   0.5   69    13068.0
# 2   -0.5     0.5    0.499   0.403560     0.499   0.5   63     6482.0
# 3    0.5     0.5    0.499   0.403560     0.499   0.5   63     6482.0
# 4   -0.5     0.5    0.499   0.403560     0.499   0.5   63     6482.0

# %%
##Valid arguments for side are "more than", "less than", "exactly"
def get_age(dataset, age, side): 
    dataset['age']=pd.to_numeric(dataset['age'])
    if(side=="more than"):
        new_data=dataset['age']>age
    elif(side=="less than"):
        new_data=dataset['age']<age
    elif(side=="exactly"):
        new_data=dataset['age']==age
    else:
        print("age direction not given, ignoring age filter")
        return dataset   
    
    return dataset[new_data]

# %%
x=get_age(congress,64, side="d")
x.head()
# Out:
# age direction not given, ignoring age filter
#    Unnamed: 0  Trinary_Score  Vader_Score  \
# 0           0              1       0.5719
# 1           1             -1      -0.1027
# 2           2             -1      -0.3182
# 3           3              0       0.0000
# 4           4             -1      -0.6249
#
#                                                 text    elite  retweet_count  \
# 0  @jnblsm Thanks for reaching out.  Wes Scherman...  _Hunter              8
# 1  .@sdut Let\xe2\x80\x99s make America great aga...  _Hunter            155
# 2  'This afternoon I'm meeting w/ White House to ...  Abraham              2
# 3  My statement on the FEMA 90-10 cost-share anno...  Abraham              3
# 4  Louisiana congressional delegation wrote to FE...  Abraham              1
#
#    media  gender  dw_extr  dwextr_rs  dw_score  race  age  followers
# 0   -0.5     0.5    0.511   0.413264     0.511   0.5   69    13068.0
# 1    0.5     0.5    0.511   0.413264     0.511   0.5   69    13068.0
# 2   -0.5     0.5    0.499   0.403560     0.499   0.5   63     6482.0
# 3    0.5     0.5    0.499   0.403560     0.499   0.5   63     6482.0
# 4   -0.5     0.5    0.499   0.403560     0.499   0.5   63     6482.0

# %%
###direction takes "above", "below", "exactly"
def get_sentiment_number(dataset, number, direction):
    if (number>1 or number<-1):
        print("\n"+"invalid number range, retruning entire dataset")
        return dataset
    
    if (direction=="above"):
        new_data=dataset['Vader_Score']>number
    elif(direction=="below"):
        new_data=dataset['Vader_Score']<number
    elif(direction=="exactly"):
        new_data=dataset['Vader_Score']==number
    else:
        print ("invalid direction given, returning entire dataset")
        return dataset
    
    
    return dataset[new_data]

# %%
get_sentiment_number(congress, 10, 'below')
# Out:
# invalid number range, retruning entire dataset
#         Unnamed: 0  Trinary_Score  Vader_Score  \
# 0                0              1       0.5719
# 1                1             -1      -0.1027
# 2                2             -1      -0.3182
# 3                3              0       0.0000
# 4                4             -1      -0.6249
# 5                5              1       0.5719
# 6                6              1       0.5255
# 7                7             -1      -0.6249
# 8                8             -1      -0.1027
# 9                9              0       0.0000
# 10              10              0       0.0000
# 11              11              1       0.0258
# 12              12              1       0.6588
# 13              13              0       0.0000
# 14              14             -1      -0.6249
# 15              15              1       0.7351
# 16              16              1       0.4019
# 17              17              0       0.0000
# 18              18              1       0.4404
# 19              19              1       0.7959
# 20              20              1       0.5093
# 21              21              1       0.8996
# 22              22              1       0.5255
# 23              23              1       0.0160
# 24              24              1       0.7650
# 25              25             -1      -0.4767
# 26              26              1       0.7639
# 27              27              1       0.4404
# 28              28              1       0.5707
# 29              29              1       0.7644
# ...            ...            ...          ...
# 276720      276720             -1      -0.9460
# 276721      276721             -1      -0.8126
# 276722      276722              1       0.4939
# 276723      276723             -1      -0.7845
# 276724      276724              0       0.0000
# 276725      276725             -1      -0.2500
# 276726      276726              1       0.8221
# 276727      276727             -1      -0.7506
# 276728      276728             -1      -0.6597
# 276729      276729              1       0.1280
# 276730      276730              1       0.9493
# 276731      276731              1       0.7177
# 276732      276732             -1      -0.5267
# 276733      276733              1       0.8316
# 276734      276734              1       0.6249
# 276735      276735              0       0.0000
# 276736      276736              1       0.1779
# 276737      276737              1       0.7184
# 276738      276738              1       0.8591
# 276739      276739              1       0.3818
# 276740      276740              0       0.0000
# 276741      276741              1       0.7184
# 276742      276742              1       0.7579
# 276743      276743              1       0.4588
# 276744      276744             -1      -0.1027
# 276745      276745              1       0.2500
# 276746      276746              1       0.3818
# 276747      276747             -1      -0.1531
# 276748      276748              1       0.6369
# 276749      276749              1       0.7574
#
#                                                      text       elite  \
# 0       @jnblsm Thanks for reaching out.  Wes Scherman...     _Hunter
# 1       .@sdut Let\xe2\x80\x99s make America great aga...     _Hunter
# 2       'This afternoon I'm meeting w/ White House to ...     Abraham
# 3       My statement on the FEMA 90-10 cost-share anno...     Abraham
# 4       Louisiana congressional delegation wrote to FE...     Abraham
# 5       Happy to announce $1.8 million in fed funds fo...     Abraham
# 6       Proud to announce that @LATech will recent $6 ...     Abraham
# 7       #LA05 parishes E. Fel, Tangipahoa, St. Landry ...     Abraham
# 8       Also visited flood command center in Amite. Ou...     Abraham
# 9       At a flood shelter in Amite. Please keep these...     Abraham
# 10      My statement on the FBI, Clinton: https://t.co...     Abraham
# 11      'My bill amends Title IX to prevent President'...     Abraham
# 12      Thanks to @ULM_Official for allowing me to sha...     Abraham
# 13      'My statement on the President's transgender b...     Abraham
# 14      See attached for list of new parishes now unde...     Abraham
# 15      'NELA is flooded, but so is southern part of #...     Abraham
# 16      'Yesterday's update on how my office has been ...     Abraham
# 17      In Ruston w/ Sheriff Stone. On phone w/ @GSU_T...     Abraham
# 18      'Met w/ OPPJ's Walt Caldwell &amp; Sheriff Rus...     Abraham
# 19      Great meeting these student body presidents fr...     Abraham
# 20             Welcome back to Earth, #ScottKelly! #LA05'     Abraham
# 21      Justice Scalia was a beacon of conservatism, a...     Abraham
# 22      Making friends at the #AgExpo in West Monroe! ...     Abraham
# 23      'The South should not be a dumping ground for ...     Abraham
# 24      'Easily the best thing about tonight's #SOTU w...     Abraham
# 25      POTUS exec. order on guns is a gross overreach...     Abraham
# 26      Welcome home to @LANationalGuard 1023rd Engine...     Abraham
# 27      I voted against the omnibus. It spends too muc...     Abraham
# 28      Congrats to #Neville on back-to-back state tit...     Abraham
# 29      Congrats to #Kentwood on the 1A state champion...     Abraham
# ...                                                   ...         ...
# 276720  'If we're serious about terrorism, let's stop ...  ZoeLofgren
# 276721  Refugees From War Aren\xe2\x80\x99t the Enemy ...  ZoeLofgren
# 276722  Syrian refugees undergo 18-24 months of backgr...  ZoeLofgren
# 276723  Using the Paris tragedy to shut down the U.S. ...  ZoeLofgren
# 276724  '.@HouseGOP's refugee bill would immediately s...  ZoeLofgren
# 276725  Welcoming #refugees who are fleeing persecutio...  ZoeLofgren
# 276726  Had a great time at the 12th annual Festival d...  ZoeLofgren
# 276727  My thoughts and prayers for the victims of sen...  ZoeLofgren
# 276728  @PanCAN @PanCANBayArea I #WageHope for the nea...  ZoeLofgren
# 276729  Proud today to wear purple and #WageHope in th...  ZoeLofgren
# 276730  '@RepSamFarr\xe2\x80\x99s commitment to public...  ZoeLofgren
# 276731  On #VeteransDay we honor those who have served...  ZoeLofgren
# 276732  #DAPA &amp; #DACA ruling by 5th circuit unders...  ZoeLofgren
# 276733  '@WhiteHouse is right to appeal #DAPA &amp; #D...  ZoeLofgren
# 276734  Great meeting a constituent of mine with the @...  ZoeLofgren
# 276735  'California Democrats are urging @CMSGov for t...  ZoeLofgren
# 276736  House Democrats seek answers &amp; solutions t...  ZoeLofgren
# 276737  1/3 retirees lives on about $1300/month. In my...  ZoeLofgren
# 276738  Proud to join @HouseDemocrats in committing to...  ZoeLofgren
# 276739  Businesses #MakeItInAmerica when government wo...  ZoeLofgren
# 276740  We\xe2\x80\x99re not going to #MakeItInAmerica...  ZoeLofgren
# 276741  Proud to discuss how my #RedistrictingReformAc...  ZoeLofgren
# 276742  Glad to receive @NACoTweets County Alumni Awar...  ZoeLofgren
# 276743  'It's been nearly 4 months since the @HouseGOP...  ZoeLofgren
# 276744  .@HouseDemocrats to GOP: "We categorically rej...  ZoeLofgren
# 276745  .@HouseDemocrats sent a letter to Speaker Boeh...  ZoeLofgren
# 276746  'I'm leading an effort to protect veterans gro...  ZoeLofgren
# 276747  Disappointed my GOP colleagues voted against g...  ZoeLofgren
# 276748  'When teachers, parents, and kids talk about b...  ZoeLofgren
# 276749  Exciting day at #USPTOSV opening today! Local ...  ZoeLofgren
#
#         retweet_count  media  gender  dw_extr  dwextr_rs  dw_score  race  age  \
# 0                   8   -0.5     0.5    0.511   0.413264     0.511   0.5   69
# 1                 155    0.5     0.5    0.511   0.413264     0.511   0.5   69
# 2                   2   -0.5     0.5    0.499   0.403560     0.499   0.5   63
# 3                   3    0.5     0.5    0.499   0.403560     0.499   0.5   63
# 4                   1   -0.5     0.5    0.499   0.403560     0.499   0.5   63
# 5                   4   -0.5     0.5    0.499   0.403560     0.499   0.5   63
# 6                   9   -0.5     0.5    0.499   0.403560     0.499   0.5   63
# 7                   0   -0.5     0.5    0.499   0.403560     0.499   0.5   63
# 8                   6    0.5     0.5    0.499   0.403560     0.499   0.5   63
# 9                   4    0.5     0.5    0.499   0.403560     0.499   0.5   63
# 10                 11    0.5     0.5    0.499   0.403560     0.499   0.5   63
# 11                 19   -0.5     0.5    0.499   0.403560     0.499   0.5   63
# 12                  4    0.5     0.5    0.499   0.403560     0.499   0.5   63
# 13                 20    0.5     0.5    0.499   0.403560     0.499   0.5   63
# 14                  1    0.5     0.5    0.499   0.403560     0.499   0.5   63
# 15                  6    0.5     0.5    0.499   0.403560     0.499   0.5   63
# 16                  7    0.5     0.5    0.499   0.403560     0.499   0.5   63
# 17                  3    0.5     0.5    0.499   0.403560     0.499   0.5   63
# 18                  1    0.5     0.5    0.499   0.403560     0.499   0.5   63
# 19                  2    0.5     0.5    0.499   0.403560     0.499   0.5   63
# 20                  0   -0.5     0.5    0.499   0.403560     0.499   0.5   63
# 21                  0   -0.5     0.5    0.499   0.403560     0.499   0.5   63
# 22                  2    0.5     0.5    0.499   0.403560     0.499   0.5   63
# 23                  2   -0.5     0.5    0.499   0.403560     0.499   0.5   63
# 24                  1   -0.5     0.5    0.499   0.403560     0.499   0.5   63
# 25                  3   -0.5     0.5    0.499   0.403560     0.499   0.5   63
# 26                  5    0.5     0.5    0.499   0.403560     0.499   0.5   63
# 27                  6   -0.5     0.5    0.499   0.403560     0.499   0.5   63
# 28                  3   -0.5     0.5    0.499   0.403560     0.499   0.5   63
# 29                  1   -0.5     0.5    0.499   0.403560     0.499   0.5   63
# ...               ...    ...     ...      ...        ...       ...   ...  ...
# 276720             28   -0.5    -0.5    0.401   0.401000    -0.401   0.5   70
# 276721              7   -0.5    -0.5    0.401   0.401000    -0.401   0.5   70
# 276722              5   -0.5    -0.5    0.401   0.401000    -0.401   0.5   70
# 276723              6   -0.5    -0.5    0.401   0.401000    -0.401   0.5   70
# 276724              3   -0.5    -0.5    0.401   0.401000    -0.401   0.5   70
# 276725              5   -0.5    -0.5    0.401   0.401000    -0.401   0.5   70
# 276726              2    0.5    -0.5    0.401   0.401000    -0.401   0.5   70
# 276727              2    0.5    -0.5    0.401   0.401000    -0.401   0.5   70
# 276728              1   -0.5    -0.5    0.401   0.401000    -0.401   0.5   70
# 276729              1    0.5    -0.5    0.401   0.401000    -0.401   0.5   70
# 276730              0   -0.5    -0.5    0.401   0.401000    -0.401   0.5   70
# 276731              2   -0.5    -0.5    0.401   0.401000    -0.401   0.5   70
# 276732              6   -0.5    -0.5    0.401   0.401000    -0.401   0.5   70
# 276733              1   -0.5    -0.5    0.401   0.401000    -0.401   0.5   70
# 276734              0    0.5    -0.5    0.401   0.401000    -0.401   0.5   70
# 276735              1   -0.5    -0.5    0.401   0.401000    -0.401   0.5   70
# 276736            190   -0.5    -0.5    0.401   0.401000    -0.401   0.5   70
# 276737             18   -0.5    -0.5    0.401   0.401000    -0.401   0.5   70
# 276738              8   -0.5    -0.5    0.401   0.401000    -0.401   0.5   70
# 276739              0   -0.5    -0.5    0.401   0.401000    -0.401   0.5   70
# 276740              0   -0.5    -0.5    0.401   0.401000    -0.401   0.5   70
# 276741              1    0.5    -0.5    0.401   0.401000    -0.401   0.5   70
# 276742              3    0.5    -0.5    0.401   0.401000    -0.401   0.5   70
# 276743              1   -0.5    -0.5    0.401   0.401000    -0.401   0.5   70
# 276744              2   -0.5    -0.5    0.401   0.401000    -0.401   0.5   70
# 276745              1   -0.5    -0.5    0.401   0.401000    -0.401   0.5   70
# 276746              0   -0.5    -0.5    0.401   0.401000    -0.401   0.5   70
# 276747              0   -0.5    -0.5    0.401   0.401000    -0.401   0.5   70
# 276748              4   -0.5    -0.5    0.401   0.401000    -0.401   0.5   70
# 276749              2    0.5    -0.5    0.401   0.401000    -0.401   0.5   70
#
#         followers
# 0         13068.0
# 1         13068.0
# 2          6482.0
# 3          6482.0
# 4          6482.0
# 5          6482.0
# 6          6482.0
# 7          6482.0
# 8          6482.0
# 9          6482.0
# 10         6482.0
# 11         6482.0
# 12         6482.0
# 13         6482.0
# 14         6482.0
# 15         6482.0
# 16         6482.0
# 17         6482.0
# 18         6482.0
# 19         6482.0
# 20         6482.0
# 21         6482.0
# 22         6482.0
# 23         6482.0
# 24         6482.0
# 25         6482.0
# 26         6482.0
# 27         6482.0
# 28         6482.0
# 29         6482.0
# ...           ...
# 276720    26975.0
# 276721    26975.0
# 276722    26975.0
# 276723    26975.0
# 276724    26975.0
# 276725    26975.0
# 276726    26975.0
# 276727    26975.0
# 276728    26975.0
# 276729    26975.0
# 276730    26975.0
# 276731    26975.0
# 276732    26975.0
# 276733    26975.0
# 276734    26975.0
# 276735    26975.0
# 276736    26975.0
# 276737    26975.0
# 276738    26975.0
# 276739    26975.0
# 276740    26975.0
# 276741    26975.0
# 276742    26975.0
# 276743    26975.0
# 276744    26975.0
# 276745    26975.0
# 276746    26975.0
# 276747    26975.0
# 276748    26975.0
# 276749    26975.0
#
# [276750 rows x 14 columns]

# %%
##pnn takes "positive,", "negative", "neutral".  
def get_sentiment_type(dataset, pnn):
    if (pnn=='positive'):
        new_data=dataset['Trinary_Score']==1
    elif (pnn=='negative'):
        new_data=dataset['Trinary_Score']==-1
    elif (pnn=='neutral'):
        new_data=dataset['Trinary_Score']==0
    else:
        print("invalid type given, returning entire dataset")
        return dataset
    
    return dataset[new_data]

# %%
##pnn takes "positive,", "negative", "neutral".  
def get_sentiment_count(dataset, pnn):
    num=get_sentiment_type(dataset,pnn).shape[0]
    return num

# %%
##Gender takes "male or "female"
def get_gender(dataset, gender):
    if(gender==male):
        new_data=dataset['gender']==0.5
    elif(gender=="female"):
        new_data=dataset['gender']==-0.5
    else:
        print("invalid gender given, returning entire dataset")
        return dataset
    
    return dataset[new_data]

# %%
##leans takes liberal or conservative
def get_leaning_tweets(dataset, leans):
    if(leans=="conservative"):
        new_data=dataset['dw_score']>0
    elif(leans=="liberal"):
        new_data=dataset['dw_score']<0
    else:
        print("invalid leaning given, returning entire dataset")
        return dataset
    
    return dataset[new_data]

# %%
def get_total_tweet_count(dataset):
    total, ignore =dataset.shape
    return total

# %%
def get_persons_tweet_count(dataset, name):
    pertinent=dataset['elite']==name
    return get_total_tweet_count(dataset[pertinent])

# %%
def get_persons_tweets(dataset,name):
    pertinent=dataset['elite']==name
    return dataset[pertinent]

# %%
def get_total_retweet_count(dataset):
    the_sum=dataset['retweet_count'].sum()
    return the_sum

# %%
def get_retweets_per_tweet(dataset):
    rt=get_total_retweet_count(dataset)
    tw=get_total_tweet_count(dataset)
    ans=rt/tw
    return ans

# %%
def get_top_retweeted(dataset, num):
    rts=[]
    ranks={}
    final={}
    all_names=dataset['elite'].unique()
    for name in all_names:
        w=get_persons_tweets(dataset,name)
        x=get_retweets_per_tweet(w)
        rts.append(x)
    for d,c in zip(all_names,rts):
        ranks.update({d:c})
    ranks_sorted=sorted(ranks, key=ranks.get, reverse=True)
    for name in ranks_sorted[0:num]:
        final.update({name:ranks[name]})
    return final

# %%
def get_average_sentiment(dataset):
    num=dataset.shape[0]
    sent=dataset['Vader_Score'].sum()
    return sent/num

# %%
get_average_sentiment(get_persons_tweets(congress, "_Hunter"))
# Out:
# 0.23459999999999998

# %%
get_top_retweeted(congress,5)
# Out:
# {'SenSanders': 2112.639595959596,
#  'repjohnlewis': 1915.8815789473683,
#  'senwarren': 854.4672566371681,
#  'tedcruz': 493.4691891891892,
#  'marcorubio': 360.64257703081233}

# %%
def get_leaning_score(dataset,name):
    score=get_persons_tweets(dataset,name)['dw_score'].max()
    return score

# %%
for name in all_names:
    get_leaning_score(congress,name)

# %%
get_leaning_score(congress,"_Hunter")
# Out:
# 0.511

# %%
def get_most_conservative(dataset,num):
    rts=[]
    ranks={}
    final={}
    all_names=dataset['elite'].unique()
    for name in all_names:
        score=get_leaning_score(dataset,name)
        rts.append(score)
    for d,c in zip(all_names,rts):
        ranks.update({d:c})
    ranks_sorted=sorted(ranks, key=ranks.get, reverse=True)
    for name in ranks_sorted[0:num]:
        final.update({name:ranks[name]})
    return final

# %%
get_most_conservative(congress,5)
# Out:
# {'SenMikeLee': 0.919,
#  'RandPaul': 0.875,
#  'tedcruz': 0.86,
#  'JeffFlake': 0.855,
#  'DaveBrat': 0.847}

# %%
def get_most_liberal(dataset,num):
    rts=[]
    ranks={}
    final={}
    all_names=dataset['elite'].unique()
    for name in all_names:
        score=get_leaning_score(dataset,name)
        rts.append(score)
    for d,c in zip(all_names,rts):
        ranks.update({d:c})
    ranks_sorted=sorted(ranks, key=ranks.get, reverse=False)
    for name in ranks_sorted[0:num]:
        final.update({name:ranks[name]})
    return final

# %%
get_most_liberal(congress,6)
# Out:
# {'senwarren': -0.7440000000000001,
#  'BarbaraLee': -0.685,
#  'MaxineWaters': -0.659,
#  'JohnConyers': -0.6579999999999999,
#  'CoryBooker': -0.621,
#  'janschakowsky': -0.604}

# %%
##Race is "white", or "not white"
def get_race_type(dataset, race):
    if(race=="white"):
        new_data=dataset['race']==0.5
    elif(race=="not white"):
        new_data=dataset['race']==-0.5
    else:
        print("invalid race entered, returning entire dataset")
        return dataset
    return dataset[new_data]

# %%
##pnn takes "positive,", "negative", "neutral".  
def get_sentiment_frequency(dataset,pnn):
    count=get_sentiment_type(dataset,pnn).shape[0]
    tot=dataset.shape[0]
    return count/tot

# %%
get_sentiment_frequency(trump,'negative')
# Out:
# 0.278264497288277

# %%
def get_most_positive(dataset,num):
    rts=[]
    ranks={}
    final={}
    all_names=dataset['elite'].unique()
    for name in all_names:
        dataset2=get_persons_tweets(dataset,name)
        score=get_average_sentiment(dataset2)
        rts.append(score)
    for d,c in zip(all_names,rts):
        ranks.update({d:c})
    ranks_sorted=sorted(ranks, key=ranks.get, reverse=True)
    for name in ranks_sorted[0:num]:
        final.update({name:ranks[name]})
    return final

# %%
get_most_positive(congress,10)
# Out:
# {'Moolenaar': 0.5405666666666666,
#  'MoBrooks': 0.533193661971831,
#  'TimWalz': 0.5221847517730497,
#  'SenJohnHoeven': 0.49654821428571433,
#  'JimLangevin': 0.49486527249683154,
#  'JimCosta': 0.47591818181818185,
#  'SenJackReed': 0.4742160714285714,
#  'CongressmanHice': 0.46851613545816734,
#  'RodBlum': 0.4644761165048545,
#  'KYComer': 0.4632792397660818}

# %%
def get_most_negative(dataset,num):
    rts=[]
    ranks={}
    final={}
    all_names=dataset['elite'].unique()
    for name in all_names:
        dataset2=get_persons_tweets(dataset,name)
        score=get_average_sentiment(dataset2)
        rts.append(score)
    for d,c in zip(all_names,rts):
        ranks.update({d:c})
    ranks_sorted=sorted(ranks, key=ranks.get, reverse=False)
    for name in ranks_sorted[0:num]:
        final.update({name:ranks[name]})
    return final
